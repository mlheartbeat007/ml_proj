# %%
import pandas as pd
## this is loading data from a csv file
df=pd.read_csv('ZILLOW-Z77006_ZRIMFRR.csv')
##df = pd.read_csv('folename')

# %%
df.head()
# Out:
#          Date   Value
# 0  2018-03-31  1429.0
# 1  2018-02-28  1434.0
# 2  2018-01-31  1444.0
# 3  2017-12-31  1450.0
# 4  2017-11-30  1444.0

# %%
## setting index in trhe dataframe
#this is the best way to manupulating csv file
df.set_index('Date',inplace=True)
df.head()
# Out:
#              Value
# Date
# 2018-03-31  1429.0
# 2018-02-28  1434.0
# 2018-01-31  1444.0
# 2017-12-31  1450.0
# 2017-11-30  1444.0

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot
df.plot()

# %%
##now set save the new value in anotherxsv file
df.to_csv('mod_data.csv')
## maybe you can save it but may be it is no accessible by the
##no mal csv file

# %%
df1=pd.read_csv('mod_data.csv',index_col=0)

# %%
df1.head()
# Out:
#              Value
# Date
# 2018-03-31  1429.0
# 2018-02-28  1434.0
# 2018-01-31  1444.0
# 2017-12-31  1450.0
# 2017-11-30  1444.0

# %%
df2=pd.read_csv('mod_data.csv')

# %%
df2.set_index('Date',inplace=True)
##df.set_index('label',inplace=True)

# %%
df2.head()
# Out:
#              Value
# Date
# 2018-03-31  1429.0
# 2018-02-28  1434.0
# 2018-01-31  1444.0
# 2017-12-31  1450.0
# 2017-11-30  1444.0

# %%
##we are going to change the label of the dataframe
## we can do it in that way
## featch the value in a variable and store the value in a data frame
#with pd.DataFrame(value1,value2) and the first value will set as a index
val1=df2['Value']
df2=pd.read_csv('mod_data.csv')
val2=df2['Date']
df3=pd.DataFrame(val1,val2)
df3.head()

# %%
#we can change  the label name
df3.tail()
# Out:
#              Value
# Date
# 2011-03-31  1417.0
# 2011-02-28  1392.0
# 2011-01-31  1368.0
# 2010-12-31  1335.0
# 2010-11-30  1313.0

# %%
## we can change the column by adding label or renaming label
## df.columns=['name_you_want']
df3.columns=['House_prices']

# %%
df3.head()
# Out:
#             House_prices
# Date
# 2018-03-31        1429.0
# 2018-02-28        1434.0
# 2018-01-31        1444.0
# 2017-12-31        1450.0
# 2017-11-30        1444.0

# %%
##save it to csv file
df3.to_csv('mod2data.csv')

# %%
df3.to_html('moddata.html')

# %%
### so the save in conversion is df.to_csv()
### df.to_html()

# %%
df5=pd.read_csv('mod2data.csv',names=['Date','House_prices'])
df5.head()
df5.set_index('Date')
# Out:
#             House_prices
# Date
# Date        House_prices
# 2018-03-31        1429.0
# 2018-02-28        1434.0
# 2018-01-31        1444.0
# 2017-12-31        1450.0
# 2017-11-30        1444.0
# 2017-10-31        1431.0
# 2017-09-30        1430.0
# 2017-08-31        1436.0
# 2017-07-31        1441.0
# 2017-06-30        1445.0
# 2017-05-31        1451.0
# 2017-04-30        1462.0
# 2017-03-31        1475.0
# 2017-02-28        1490.0
# 2017-01-31        1508.0
# 2016-12-31        1516.0
# 2016-11-30        1516.0
# 2016-10-31        1511.0
# 2016-09-30        1524.0
# 2016-08-31        1543.0
# 2016-07-31        1557.0
# 2016-06-30        1568.0
# 2016-05-31        1572.0
# 2016-04-30        1574.0
# 2016-03-31        1570.0
# 2016-02-29        1569.0
# 2016-01-31        1573.0
# 2015-12-31        1575.0
# 2015-11-30        1574.0
# ...                  ...
# 2013-04-30        1416.0
# 2013-03-31        1381.0
# 2013-02-28        1343.0
# 2013-01-31        1299.0
# ...
