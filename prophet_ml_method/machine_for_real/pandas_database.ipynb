# %% [markdown]
# # loding a csv data to database

# %%
import sqlite3
server = sqlite3.connect('data.db')
cursor=server.cursor()  
def create_database(cursor):
    sql='''create table if not exists data(date varchar(30) not null,value varchar(30) not null);'''
    cursor.execute(sql)
create_database(cursor)

# %%
import pandas as pd
from pandas.io import sql
server = sqlite3.connect('data.db')

# %%
cursor=server.cursor()

# %% [markdown]
# # reading csv data using pandas

# %%
#df=pd.read_csv(filename)

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          Date  Value
# 0  2018-03-31  1.408
# 1  2018-02-28  1.400
# 2  2018-01-31  1.390
# 3  2017-12-31  1.386
# 4  2017-11-30  1.380

# %% [markdown]
# # sending all data to database

# %%
#syntax df.to_sql('tablenamewithoutdbextension',connection,if_exists='replace/append')

# %%
df.to_sql("data", server, if_exists="replace")

# %% [markdown]
# # reaing data from the databases using pandas

# %%
#pd.read_sql_quary(sql,conn)
sql="select * from data"
pd.read_sql_query(sql,server)
# Out:
#     index        Date  Value
# 0       0  2018-03-31  1.408
# 1       1  2018-02-28  1.400
# 2       2  2018-01-31  1.390
# 3       3  2017-12-31  1.386
# 4       4  2017-11-30  1.380
# 5       5  2017-10-31  1.372
# 6       6  2017-09-30  1.370
# 7       7  2017-08-31  1.370
# 8       8  2017-07-31  1.378
# 9       9  2017-06-30  1.390
# 10     10  2017-05-31  1.402
# 11     11  2017-04-30  1.412
# 12     12  2017-03-31  1.408
# 13     13  2017-02-28  1.410
# 14     14  2017-01-31  1.410
# 15     15  2016-12-31  1.422
# 16     16  2016-11-30  1.434
# 17     17  2016-10-31  1.444
# 18     18  2016-09-30  1.460
# 19     19  2016-08-31  1.480
# 20     20  2016-07-31  1.498
# 21     21  2016-06-30  1.510
# 22     22  2016-05-31  1.514
# 23     23  2016-04-30  1.510
# 24     24  2016-03-31  1.528
# 25     25  2016-02-29  1.550
# 26     26  2016-01-31  1.576
# 27     27  2015-12-31  1.576
# 28     28  2015-11-30  1.578
# 29     29  2015-10-31  1.578
# ..    ...         ...    ...
# ...
